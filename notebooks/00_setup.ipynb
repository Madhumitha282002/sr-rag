# %% [markdown]
# # SR-RAG Setup Verification
# Run each cell to confirm the environment is working.

# %%
import pypdf
import fitz
import sentence_transformers
import chromadb
import streamlit
import fastapi
import langchain_text_splitters
print('All imports OK')

# %%
from configs.settings import Settings
print('RAW_PAPERS_DIR:', Settings.RAW_PAPERS_DIR)
print('LLM_MODEL:', Settings.LLM_MODEL)
